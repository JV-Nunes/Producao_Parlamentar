# %%
import pandas as pd

# %%
df = pd.read_csv('BQ/consultaBQ.csv')
dep = pd.read_excel('BQ/deputados.xlsx')
# Out:
# /home/joao/anaconda3/envs/scraping/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
dep.head()
# Out:
#                                                  uri                    nome  \
# 0  https://dadosabertos.camara.leg.br/api/v2/depu...              LOPES GAMA
# 1  https://dadosabertos.camara.leg.br/api/v2/depu...                  CALMON
# 2  https://dadosabertos.camara.leg.br/api/v2/depu...               MONTEZUMA
# 3  https://dadosabertos.camara.leg.br/api/v2/depu...  ALBUQUERQUE CAVALCANTI
# 4  https://dadosabertos.camara.leg.br/api/v2/depu...       CARNEIRO DA CUNHA
#
#    idLegislaturaInicial  idLegislaturaFinal  \
# 0                   1.0                 2.0
# 1                   1.0                 4.0
# 2                   2.0                 8.0
# 3                   3.0                 4.0
# 4                   2.0                 8.0
#
#                                 nomeCivil  cpf siglaSexo urlRedeSocial  \
# 0                Caetano Maria Lopes Gama  NaN         M           NaN
# 1          Miguel Calmon Du Pin e Almeida  NaN         M           NaN
# ...

# %%
df.dropna(subset=['nome_autor'], inplace=True)

# %%
df[df['nome_autor'].str.contains('Tabata Amaral', regex=True)]
# Out:
#          nome_autor                                     descricao_tipo  f0_
# 21    Tabata Amaral                                          Relatório    3
# 172   Tabata Amaral  Requerimento de Constituição de Comissão Espec...    1
# 782   Tabata Amaral  Requerimento de Inclusão ou Retirada de Assina...    1
# 785   Tabata Amaral  Requerimento de Retirada de assinatura em prop...    3
# 956   Tabata Amaral  Requerimento de Retirada de Proposição de Inic...    1
# 1346  Tabata Amaral                                          Indicação    3
# 1583  Tabata Amaral                                       Requerimento  112
# 1996  Tabata Amaral                                     Projeto de Lei   63
# 2688  Tabata Amaral                                 Emenda de Plenário    1
# 2904  Tabata Amaral                                 Emenda na Comissão   24
# 3085  Tabata Amaral                               Projeto de Resolução    3
# ...

# %%
deputados = list(dep.nome.unique())

# %%
for row in df[df['nome_autor'].str.contains('Senado Federal - ', regex=True)].iloc[:,0]:
    deputados.append(row)

# %%
len(df)
# Out:
# 7704

# %%
df[df['nome_autor'].str.contains('Gildenemyr', regex=True)]
# Out:
#              nome_autor                                     descricao_tipo  \
# 1195  Pastor Gildenemyr                                          Indicação
# 1293         Gildenemyr                                          Indicação
# 1503  Pastor Gildenemyr                                       Requerimento
# 1899  Pastor Gildenemyr                                     Projeto de Lei
# 2512         Gildenemyr                                     Projeto de Lei
# 2648  Pastor Gildenemyr                                 Emenda de Plenário
# 3041         Gildenemyr                                 Emenda na Comissão
# 4487         Gildenemyr                       Requerimento de Desapensação
# 4611  Pastor Gildenemyr                      Requerimento de Sessão Solene
# 5088  Pastor Gildenemyr                  Requerimento de Audiência Pública
# 5090         Gildenemyr                  Requerimento de Audiência Pública
# ...

# %%
df[-df['nome_autor'].isin(deputados)]
# Out:
#                                              nome_autor  \
# 2                                 SOS Segurança Dá Vida
# 4     Comissão Externa destinada a acompanhar as inv...
# 9             Subcomissão Especial para Assuntos Penais
# 10                Instituto Fundo Devido ao Trabalhador
# 12                     Comissão de Viação e Transportes
# ...                                                 ...
# 7333                                      Evandro Roman
# 7335                              Alencar Santana Braga
# 7394                                  Pastor Gildenemyr
# 7486  Comissão de Defesa dos Direitos das Pessoas co...
# 7579                              Alencar Santana Braga
#
#                                          descricao_tipo  f0_
# 2                                              Sugestão    4
# 4                         Relatório de Comissão Externa    1
# 9                                           Anteprojeto    8
# ...
